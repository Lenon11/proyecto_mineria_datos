# %%
import os
print("Estoy en:", os.getcwd())
# Out:
# Estoy en: c:\Users\LeninQ\Desktop\proyecto_mineria_datos\notebooks

# %%
import geopandas as gpd
gdf = gpd.read_file("../data/raw/mun_jal.geojson")
print(gdf.head())
# Out:
#   cvegeo cve_ent cve_mun                   nomgeo cve_cab pob_total  \
# 0  14089      14     089  Techaluta de Montenegro    0001      4072
# 1  14094      14     094                  Tequila    0001     44353
# 2  14095      14     095               Teuchitlán    0001      9647
# 3  14096      14     096          Tizapán el Alto    0001     22758
# 4  14032      14     032            Chiquilistlán    0001      5983
#
#   pob_femenina pob_masculina total_viviendas_habitadas  \
# 0         2061          2011                      1096
# 1        22462         21891                     11150
# 2         4938          4709                      2712
# 3        11579         11179                      6317
# 4         3008          2975                      1468
#
#                                             geometry
# 0  MULTIPOLYGON (((-103.56717 20.14875, -103.5668...
# 1  MULTIPOLYGON (((-103.53858 21.44441, -103.5384...
# 2  MULTIPOLYGON (((-103.78641 20.78581, -103.7868...
# ...
